# %%
import pandas as pd
from pymongo import MongoClient

client = MongoClient('localhost', 27017)
db = client.sports_betting_capstone
nfl_lines = db.nfl_lines

# %%
nfl_rows = nfl_lines.find()
nfl_pddf = pd.DataFrame(list(nfl_rows))
nfl_pddf
# Out:
#                            _id                Team        Win-Loss Streak  \
# 0     5f98877a1e3e51b1b60328e4         451 Houston   (0-0) (0-0 A)
# 1     5f98877a1e3e51b1b60328e5  452 Kansas City Â«   (0-0) (0-0 H)
# 2     5f98877a1e3e51b1b60328e6      0 Las Vegas Â«   (0-0) (0-0 A)
# 3     5f98877a1e3e51b1b60328e7          0 Carolina   (0-0) (0-0 H)
# 4     5f98877a1e3e51b1b60328e8           453 Miami   (0-0) (0-0 A)
# ...                        ...                 ...             ...    ...
# 2339  5f98883cc01cbbbbde303746  314 New England Â«  (14-2) (6-2 H)    W-8
# 2340  5f98883dc01cbbbbde303748             497 AFC   (0-0) (0-0 A)
# 2341  5f98883dc01cbbbbde303749             498 NFC   (0-0) (0-0 H)
# 2342  5f98883ec01cbbbbde30374b     101 New England  (14-2) (8-0 A)    W-9
# 2343  5f98883ec01cbbbbde30374c         102 Atlanta  (11-5) (5-3 H)    W-6
#
#       Open Closing Consensus_Spread Consensus_Money Consensus_OU  Season  Week
# 0     56.5    53.5              50%             26%          72%    2020     1
# 1      -10    -9.5              50%             74%          28%    2020     1
# 2                                                                   2020     1
# 3                                                                   2020     1
# 4     43.5    41.5              42%             51%          58%    2020     1
# ...    ...     ...              ...             ...          ...     ...   ...
# 2339          -5.5              55%             40%          34%    2016    20
# 2340  68.5      80              34%             69%          77%    2016    21
# 2341  -4.5      -4              66%             31%          23%    2016    21
# 2342    PK      -3              63%             47%          52%    2016    22
# 2343  56.5      57              37%             53%          48%    2016    22
#
# [2344 rows x 11 columns]

# %%
nfl_pddf.drop(['_id', 'Win-Loss', 'Streak'], axis = 1)
# Out:
#                     Team  Open Closing Consensus_Spread Consensus_Money  \
# 0            451 Houston  56.5    53.5              50%             26%
# 1     452 Kansas City Â«   -10    -9.5              50%             74%
# 2         0 Las Vegas Â«
# 3             0 Carolina
# 4              453 Miami  43.5    41.5              42%             51%
# ...                  ...   ...     ...              ...             ...
# 2339  314 New England Â«          -5.5              55%             40%
# 2340             497 AFC  68.5      80              34%             69%
# 2341             498 NFC  -4.5      -4              66%             31%
# 2342     101 New England    PK      -3              63%             47%
# 2343         102 Atlanta  56.5      57              37%             53%
#
#      Consensus_OU  Season  Week
# 0             72%    2020     1
# 1             28%    2020     1
# 2                    2020     1
# 3                    2020     1
# 4             58%    2020     1
# ...           ...     ...   ...
# 2339          34%    2016    20
# 2340          77%    2016    21
# 2341          23%    2016    21
# 2342          52%    2016    22
# 2343          48%    2016    22
#
# [2344 rows x 8 columns]

# %%
for idx, row in nfl_pddf.iterrows():
    if idx == 0 or idx % 2 == 0:
        nfl_pddf.loc[idx, 'Include'] = True
        nfl_pddf.loc[idx, 'Team 1'] = nfl_pddf.loc[idx, 'Team']
        nfl_pddf.loc[idx, 'Team 2'] = nfl_pddf.loc[idx + 1, 'Team']
        nfl_pddf.loc[idx, 'Spread Open'] = nfl_pddf.loc[idx , 'Open']
        nfl_pddf.loc[idx, 'Spread Close'] = nfl_pddf.loc[idx, 'Closing']
        nfl_pddf.loc[idx, 'Spread Consensus Team 1'] = nfl_pddf.loc[idx, 'Consensus_Spread']
        nfl_pddf.loc[idx, 'Spread Consensus Team 2'] = nfl_pddf.loc[idx + 1, 'Consensus_Spread']
        nfl_pddf.loc[idx, 'O/U Open'] = nfl_pddf.loc[idx , 'Open']
        nfl_pddf.loc[idx, 'O/U Close'] = nfl_pddf.loc[idx, 'Closing']
        nfl_pddf.loc[idx, 'Over Consensus'] = nfl_pddf.loc[idx, 'Consensus_OU']
        nfl_pddf.loc[idx, 'Under Consensus'] = nfl_pddf.loc[idx + 1, 'Consensus_OU']
        nfl_pddf.loc[idx, 'Moneyline Consensus Team 1'] = nfl_pddf.loc[idx, 'Consensus_Money']
        nfl_pddf.loc[idx, 'Moneyline Consensus Team 2'] = nfl_pddf.loc[idx + 1, 'Consensus_Money']
    else:
        nfl_pddf.loc[idx, 'Include'] = False

# %%
clean_nfl_pddf = nfl_pddf.drop(nfl_pddf.columns[range(9)], axis = 1)[nfl_pddf['Include']]

# %%
clean_nfl_pddf
# Out:
#       Season  Week Include            Team 1              Team 2 Spread Open  \
# 0       2020     1    True       451 Houston  452 Kansas City Â«        56.5
# 2       2020     1    True    0 Las Vegas Â«          0 Carolina
# 4       2020     1    True         453 Miami  454 New England Â«        43.5
# 6       2020     1    True     455 Cleveland    456 Baltimore Â«        48.5
# 8       2020     1    True     457 N.Y. Jets      458 Buffalo Â«        40.0
# ...      ...   ...     ...               ...                 ...         ...
# 2334    2016    19    True  307 Green Bay Â«          308 Dallas        51.5
# 2336    2016    20    True     311 Green Bay      312 Atlanta Â«          61
# 2338    2016    20    True    313 Pittsburgh  314 New England Â«
# 2340    2016    21    True           497 AFC             498 NFC        68.5
# 2342    2016    22    True   101 New England         102 Atlanta          PK
#
#      Spread Close Spread Consensus Team 1 Spread Consensus Team 2 O/U Open  \
# 0            53.5                     50%                     50%     56.5
# 2
# 4            41.5                     42%                     58%     43.5
# 6            47.5                     40%                     60%     48.5
# 8              39                     20%                     80%     40.0
# ...           ...                     ...                     ...      ...
# 2334         53.5                     56%                     44%     51.5
# 2336           61                     65%                     35%       61
# 2338         49.5                     45%                     55%
# 2340           80                     34%                     66%     68.5
# 2342           -3                     63%                     37%       PK
#
#      O/U Close Over Consensus Under Consensus Moneyline Consensus Team 1  \
# 0         53.5            72%             28%                        26%
# 2
# 4         41.5            58%             42%                        51%
# 6         47.5            72%             28%                        25%
# 8           39            49%             51%                        23%
# ...        ...            ...             ...                        ...
# 2334      53.5            76%             24%                        77%
# 2336        61            63%             37%                        72%
# 2338      49.5            66%             34%                        60%
# 2340        80            77%             23%                        69%
# 2342        -3            52%             48%                        47%
#
#      Moneyline Consensus Team 2
# 0                           74%
# 2
# 4                           49%
# 6                           75%
# 8                           77%
# ...                         ...
# 2334                        23%
# 2336                        28%
# 2338                        40%
# 2340                        31%
# 2342                        53%
#
# [1172 rows x 15 columns]

# %%
nfl_pddf
# Out:
#                            _id                Team        Win-Loss Streak  \
# 0     5f98877a1e3e51b1b60328e4         451 Houston   (0-0) (0-0 A)
# 1     5f98877a1e3e51b1b60328e5  452 Kansas City Â«   (0-0) (0-0 H)
# 2     5f98877a1e3e51b1b60328e6      0 Las Vegas Â«   (0-0) (0-0 A)
# 3     5f98877a1e3e51b1b60328e7          0 Carolina   (0-0) (0-0 H)
# 4     5f98877a1e3e51b1b60328e8           453 Miami   (0-0) (0-0 A)
# ...                        ...                 ...             ...    ...
# 2339  5f98883cc01cbbbbde303746  314 New England Â«  (14-2) (6-2 H)    W-8
# 2340  5f98883dc01cbbbbde303748             497 AFC   (0-0) (0-0 A)
# 2341  5f98883dc01cbbbbde303749             498 NFC   (0-0) (0-0 H)
# 2342  5f98883ec01cbbbbde30374b     101 New England  (14-2) (8-0 A)    W-9
# 2343  5f98883ec01cbbbbde30374c         102 Atlanta  (11-5) (5-3 H)    W-6
#
#       Open Closing Consensus_Spread Consensus_Money Consensus_OU  Season  ...  \
# 0     56.5    53.5              50%             26%          72%    2020  ...
# 1      -10    -9.5              50%             74%          28%    2020  ...
# 2                                                                   2020  ...
# 3                                                                   2020  ...
# 4     43.5    41.5              42%             51%          58%    2020  ...
# ...    ...     ...              ...             ...          ...     ...  ...
# 2339          -5.5              55%             40%          34%    2016  ...
# 2340  68.5      80              34%             69%          77%    2016  ...
# 2341  -4.5      -4              66%             31%          23%    2016  ...
# 2342    PK      -3              63%             47%          52%    2016  ...
# 2343  56.5      57              37%             53%          48%    2016  ...
#
#       Spread Open Spread Close Spread Consensus Team 1  \
# 0            56.5         53.5                     50%
# 1             NaN          NaN                     NaN
# 2
# 3             NaN          NaN                     NaN
# 4            43.5         41.5                     42%
# ...           ...          ...                     ...
# 2339          NaN          NaN                     NaN
# 2340         68.5           80                     34%
# 2341          NaN          NaN                     NaN
# 2342           PK           -3                     63%
# 2343          NaN          NaN                     NaN
#
#      Spread Consensus Team 2 O/U Open O/U Close Over Consensus  \
# 0                        50%     56.5      53.5            72%
# 1                        NaN      NaN       NaN            NaN
# 2
# 3                        NaN      NaN       NaN            NaN
# 4                        58%     43.5      41.5            58%
# ...                      ...      ...       ...            ...
# 2339                     NaN      NaN       NaN            NaN
# 2340                     66%     68.5        80            77%
# 2341                     NaN      NaN       NaN            NaN
# 2342                     37%       PK        -3            52%
# 2343                     NaN      NaN       NaN            NaN
#
#      Under Consensus Moneyline Consensus Team 1 Moneyline Consensus Team 2
# 0                28%                        26%                        74%
# 1                NaN                        NaN                        NaN
# 2
# 3                NaN                        NaN                        NaN
# 4                42%                        51%                        49%
# ...              ...                        ...                        ...
# 2339             NaN                        NaN                        NaN
# 2340             23%                        69%                        31%
# 2341             NaN                        NaN                        NaN
# 2342             48%                        47%                        53%
# 2343             NaN                        NaN                        NaN
#
# [2344 rows x 24 columns]
